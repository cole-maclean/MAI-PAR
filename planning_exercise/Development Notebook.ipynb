# %%
import Planner
import importlib
importlib.reload(Planner)
# Out:
# <module 'Planner' from 'C:\\Users\\macle\\Desktop\\UPC Masters\\Semester 2\\PAR\\planning_exercise\\Planner.py'>

# %%
my_planner = Planner.Planner({'robot-location': 3, 'steps': 0, 'petitions': {2: 1, 10: 3, 11: 1, 12: 2, 24: 1}, 'robot-free': True, 'robot-loaded': 0, 'machines': {3: 3, 7: 1, 20: 2, 22: 1,30:2}, 'served': []},36)

# %%
acts = my_planner.possible_actions()

# %%
my_planner.select_action(acts)
# Out:
# ['make', [3, 1]]

# %%
my_planner.build_plan()
# Out:
# 3
# 2
# 3
# 11
# 3
# 24
# 3
# 2
# 2
# 3
# 2
# 7
# 2
# 20
# 2
# 22
# 2
# 30
# 2
# 20
# 20
# 11
# 20
# 24
# 20
# 24
# 24
# 3
# 24
# 7
# 24
# 20
# 24
# 22
# 24
# 30
# 24
# 30
# 30
# 11
# 30
# 11
# 11
# 3
# 11
# 20
# 11
# 30
# 11
# 3
# 3
# 12
# 3
# 12
# 12
# 3
# 12
# 3
# 3
# 10
# 3
# 10
# [{'action': 'initialize',
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {2: 1, 10: 3, 11: 1, 12: 2, 24: 1},
#    'robot-free': True,
#    'robot-loaded': 0,
#    'robot-location': 3,
#    'served': [],
#    'steps': 0}},
#  {'action': ['make', [3, 1]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {2: 1, 10: 3, 11: 1, 12: 2, 24: 1},
#    'robot-free': False,
#    'robot-loaded': 1,
#    'robot-location': 3,
#    'served': [],
#    'steps': 0}},
#  {'action': ['move', [3, 2]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {2: 1, 10: 3, 11: 1, 12: 2, 24: 1},
#    'robot-free': False,
#    'robot-loaded': 1,
# ...

# %%
my_planner.plan
# Out:
# [{'action': ['move', [0, 3]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {},
#    'robot-free': True,
#    'robot-loaded': 0,
#    'robot-location': 12,
#    'served': [10, 2, 11, 24, 12],
#    'steps': 42}},
#  {'action': ['make', [3, 3]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {},
#    'robot-free': True,
#    'robot-loaded': 0,
#    'robot-location': 12,
#    'served': [10, 2, 11, 24, 12],
#    'steps': 42}},
#  {'action': ['move', [3, 10]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {},
#    'robot-free': True,
#    'robot-loaded': 0,
#    'robot-location': 12,
#    'served': [10, 2, 11, 24, 12],
#    'steps': 42}},
#  {'action': ['serve', [10, 3]],
#   'state': {'machines': {3: 3, 7: 1, 20: 2, 22: 1, 30: 2},
#    'petitions': {},
#    'robot-free': True,
#    'robot-loaded': 0,
#    'robot-location': 12,
#    'served': [10, 2, 11, 24, 12],
#    'steps': 42}},
# ...
